# %%
import numpy as np
import style
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
class LinearRegression:
    def __init__(self, lr=0.01):
        self.lr=lr
    def fit(self,x,y):
        self.x=x
        self.y=y
        self.w=np.random.random()
        self.b=np.random.random()
        self.gradient_descent()
#         return w,b
    def gradient_descent(self):
#         cost_init=self.cost(self.w,self.b)
        for i in range(50):
            self.w-=self.lr*self.diff_w()
            self.b-=self.lr*self.diff_b()
            cost=self.cost(self.w,self.b)
    def cost(self,w,b):
        y_pred=w*x+b
        y2=y_pred-y
        cost=np.sum((y2)**2)/(2*len(x))
        return cost
    def diff_w(self):
        diff_w=np.dot(2*self.cost(self.w,self.b),self.x)
        return diff_w
    def diff_b(self):
        diff_b=2*self.cost(self.w,self.b)
        return diff_b
    def predict(self,x):
        y_new=self.w*x+self.b
        return y_new

# %%
bias=100
x,y,coef=make_regression(n_samples=100, n_features=1,bias=100,noise=10, random_state=42, coef=True)

# %%
y_new=coef*x+bias
plt.scatter(x,y)
plt.plot(x,y_new,'g')
plt.show()

# %%
y_new=coef*x+bias
plt.scatter(x,y)
# plt.plot(x,y_new,'g')
model=LinearRegression()
model.fit(x,y)
y_new2=model.predict(x)
plt.plot(x,y_new2,'r')
plt.show()
# Out:
# C:\Users\soham\AppData\Local\Temp\ipykernel_6000\3846018821.py:20: RuntimeWarning: overflow encountered in square
#   cost=np.sum((y2)**2)/(2*len(x))
